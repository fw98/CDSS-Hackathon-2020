# %%
import pandas as pd
unitedkingdompolicy=pd.read_csv('unitedkingdompolicy.csv')

# %%
policycolumns=['date',
 'school_closing',
 'school_closing_flag',
 'workplace_closing',
 'workplace_closing_flag',
 'cancel_public_events',
 'cancel_public_events_flag',
 'restrictions_on_gatherings',
 'restrictions_on_gatherings_flag',
 'close_public_transit',
 'close_public_transit_flag',
 'stay_at_home_requirements',
 'stay_at_home_requirements_flag',
 'restrictions_on_internal_movement',
 'restrictions_on_internal_movement_flag',
 'international_travel_controls',
 'income_support',
 'income_support_flag',
 'debt_contract_relief',
 'fiscal_measures',
 'international_support',
 'public_information_campaigns',
 'public_information_campaigns_flag',
 'testing_policy',
 'contact_tracing',
 'emergency_healthcare_investment',
 'vaccine_investment',
 'misc_wildcard',
 'confirmed_cases',
 'deaths',
 'stringency_index']

# %%
unitedkingdompolicy=unitedkingdompolicy[policycolumns].sort_values('date')

# %%
unitedkingdompolicy['count']=unitedkingdompolicy.count(axis=1)

# %%
indices=[]
for i in range(0,1320,5):
    subset=unitedkingdompolicy.iloc[i:i+5]
    indices.append(subset['count'].argmax())
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning:
# The current behaviour of 'Series.argmax' is deprecated, use 'idxmax'
# instead.
# The behavior of 'argmax' will be corrected to return the positional
# maximum in the future. For now, use 'series.values.argmax' or
# 'np.argmax(np.array(values))' to get the position of the maximum
# row.
#   after removing the cwd from sys.path.

# %%
indices
# Out:
# [127,
#  128,
#  129,
#  130,
#  131,
#  132,
#  133,
#  134,
#  135,
#  136,
#  137,
#  138,
#  139,
#  140,
#  141,
#  142,
#  143,
#  144,
#  145,
#  222,
#  223,
#  224,
#  225,
#  226,
#  227,
#  228,
#  229,
#  230,
#  231,
#  232,
#  283,
#  284,
#  285,
#  286,
#  287,
#  288,
#  289,
#  290,
#  291,
#  292,
#  293,
#  294,
#  295,
#  296,
#  297,
#  298,
#  299,
#  300,
#  301,
#  302,
#  303,
#  304,
#  305,
#  306,
#  307,
#  308,
#  309,
#  310,
#  311,
#  312,
#  313,
#  314,
#  315,
#  316,
#  317,
#  318,
#  319,
#  527,
#  528,
#  529,
#  323,
#  324,
#  325,
#  326,
#  327,
#  947,
#  948,
#  949,
#  950,
#  951,
#  952,
#  953,
#  335,
#  955,
#  751,
#  1166,
#  1167,
#  340,
#  548,
#  342,
#  343,
#  963,
#  964,
#  346,
#  1175,
#  348,
#  968,
#  350,
#  970,
#  352,
#  767,
#  1182,
#  1183,
#  563,
#  1185,
#  358,
#  1187,
#  1188,
#  568,
#  776,
#  982,
#  571,
#  1193,
#  1194,
#  986,
#  575,
#  783,
#  370,
#  371,
#  991,
#  373,
#  788,
#  375,
# ...

# %%
unitedkingdompolicy=unitedkingdompolicy.loc[indices]

# %%
unitedkingdompolicy.to_csv('unitedkingdompolicy.csv')
